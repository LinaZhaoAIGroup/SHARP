# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from skimage.io import imread,imsave
from skimage.transform import radon, iradon, iradon_sart
import time
import os
import torch
from skimage.metrics import peak_signal_noise_ratio as PSNR
from torchmetrics.image import MultiScaleStructuralSimilarityIndexMeasure
from model.function import rmse
import skimage.io as io

# %%
ours=imread("/home/zhengmao/hbtask/SHARP/data/bamboo_data/result/recon_001001.tif")
plt.figure(figsize=(20,15))
fig,ax=plt.subplots()
ax.imshow(ours,cmap='gray')
    
zoom_width=150
zoom_height=150

rect=plt.Rectangle((470,180),zoom_width,zoom_height,fill=False,color="red")
ax.add_patch(rect)
ax_zoom =fig.add_axes([0.467,-0.20,0.38,0.38])

#ax_zoom.set_xlim([0,150])
    #ax_zoom.set_ylim([0,150])
ax_zoom.imshow(ours[180:330,470:620],cmap='gray')
rect=plt.Rectangle((0,0),zoom_width-1,zoom_height-1,fill=False,color="r")
ax_zoom.add_patch(rect)

rect=plt.Rectangle((150,150),zoom_width,zoom_height,fill=False,color="b")
ax.add_patch(rect)



ax_zoom2=fig.add_axes([0.176,-0.20,0.38,0.38])
ax_zoom2.imshow(ours[150:300,150:300],cmap='gray',vmin=0,vmax=1)
rect=plt.Rectangle((0,0),zoom_width-2,zoom_height-2,fill=False,color="b")
ax_zoom2.add_patch(rect)
    
ax_zoom.axis('off')
ax_zoom2.axis('off')
ax.axis('off')
    
plt.show()

# %%
ours=imread("/home/zhengmao/hbtask/SHARP/data/Shrimp-Leg_data/result/recon_001001.tif")
plt.figure(figsize=(20,15))
fig,ax=plt.subplots()
ax.imshow(ours,cmap='gray')
    
zoom_width=300
zoom_height=300

rect=plt.Rectangle((650,650),zoom_width,zoom_height,fill=False,color="red")
ax.add_patch(rect)
ax_zoom =fig.add_axes([0.467,-0.20,0.38,0.38])

#ax_zoom.set_xlim([0,150])
    #ax_zoom.set_ylim([0,150])
ax_zoom.imshow(ours[650:950,650:950],cmap='gray')
rect=plt.Rectangle((0,0),zoom_width-1,zoom_height-1,fill=False,color="r")
ax_zoom.add_patch(rect)

rect=plt.Rectangle((150,150),zoom_width,zoom_height,fill=False,color="b")
ax.add_patch(rect)



ax_zoom2=fig.add_axes([0.176,-0.20,0.38,0.38])
ax_zoom2.imshow(ours[150:450,150:450],cmap='gray',vmin=0,vmax=1)
rect=plt.Rectangle((0,0),zoom_width-2,zoom_height-2,fill=False,color="b")
ax_zoom2.add_patch(rect)
    
ax_zoom.axis('off')
ax_zoom2.axis('off')
ax.axis('off')
    
plt.show()
